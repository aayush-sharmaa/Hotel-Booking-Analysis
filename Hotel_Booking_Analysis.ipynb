# %% [markdown]
# <a href="https://colab.research.google.com/github/aayush-sharmaa/Hotel-Booking-Analysis/blob/main/Hotel_Booking_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Hotel Booking Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# **Projected by - Ayush Sharma**

# %% [markdown]
# .

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# In the dynamic hospitality industry, understanding and leveraging data is crucial for effective decision-making. Hotel booking analysis provides a comprehensive view of customer behavior, market trends, and operational efficiency. This article explores key aspects of hotel booking analysis, emphasizing patterns, demographics, and revenue management.
#
# One of the primary objectives of hotel booking analysis is to unveil patterns in reservation data. By scrutinizing booking trends over time, businesses can identify peak periods, seasonal variations, and recurring patterns. Understanding these temporal nuances allows hotels to optimize pricing strategies, allocate resources efficiently, and provide tailored experiences during high-demand periods. Whether it's discerning a surge in weekend bookings or an annual tourist influx, recognizing patterns lays the foundation for proactive decision-making.
#
# The analysis kicks off with a focus on understanding and mitigating high cancellation rates. Unraveling the reasons behind booking cancellations is crucial for developing targeted strategies that not only retain bookings but also safeguard revenue stability. By identifying patterns and influencing factors, the project aims to provide actionable recommendations to minimize cancellations and optimize revenue outcomes.
#
# Analyzing customer demographics is pivotal for tailoring services to specific market segments. By categorizing bookings based on factors such as age, location, and purpose of travel, hotels can customize offerings to meet diverse preferences. This insight extends beyond room preferences to ancillary services, influencing marketing strategies and guest experiences. For instance, if a hotel identifies a significant influx of business travelers during weekdays, it might tailor packages to cater to their unique needs, enhancing overall customer satisfaction and loyalty.
#
# Understanding and fulfilling guest preferences, especially special requests, represent a crucial element in enhancing the overall guest experience. By exploring the nature and frequency of special requests made by guests, the project aims to implement measures that better cater to these preferences. This not only contributes to guest satisfaction but also fosters loyalty, a vital component for sustained success in the hospitality industry.
#
#
# In conclusion, this project is a holistic endeavor to leverage data insights for comprehensive improvements in hotel operations. By addressing high cancellation rates, streamlining booking processes, optimizing parking solutions, refining pricing strategies, and enhancing special request fulfillment, the project aims to equip the hotel with the knowledge and strategies needed to thrive in a competitive landscape. The outcomes are geared toward a seamless guest experience, improved operational efficiency, and a robust financial standing for the hotel.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/aayush-sharmaa/Hotel-Booking-Analysis

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# 1. Investigate the factors contributing to a high rate of booking cancellations. Develop strategies to reduce cancellations and mitigate their impact on revenue.
#
# 2. Analyze the reasons behind frequent changes in bookings. Streamline the booking modification process to enhance customer satisfaction and operational efficiency.
#
# 3. Address concerns related to insufficient parking spaces. Evaluate the feasibility of increasing parking capacity or implementing alternative solutions to meet guest demand.
#
# 4. Assess the effectiveness of the current pricing strategy, particularly the Average Daily Rate (ADR). Optimize pricing strategies to ensure they align with market dynamics and maximize revenue.
#
# 5. Investigate and understand the nature of special requests made by guests. Implement measures to better fulfill guest preferences and enhance overall service quality.
#
# 6. How can we make sure the hotel earns the most money, especially during busy times? What strategies can be implemented to optimize revenue by aligning pricing with demand patterns and seasonal variations?
#
# 7. What do our guests like, and how can we make their stay better?
# Professional: How can we leverage demographic and preference data to tailor services and enhance customer satisfaction?

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Maximizing Revenue and Enhancing Guest Satisfaction through Data-Driven Optimization
#
# Leverage lead time, booking changes, and other factors to implement dynamic pricing strategies.
# Minimize cancellations through targeted policies based on historical data.
#
# Utilize demographic and preference data to tailor services, providing a personalized experience for guests.
# Optimize room allocation based on customer preferences to enhance overall satisfaction.
# Implement strategies to encourage repeat bookings and foster customer loyalty.
#
# Efficiently allocate resources by analyzing booking patterns and adjusting staffing levels accordingly.
# Minimize days in the waiting list by optimizing room allocation and reservation processes.
# Streamline the booking experience to reduce friction for guests and improve operational efficiency.
#
# Conduct a thorough competitive analysis to understand market trends and position the hotel strategically.
# Implement marketing strategies to highlight unique offerings and attract a wider audience.
# Continuously monitor and adapt to changes in the competitive landscape.
#
# Establish a culture of data-driven decision-making within the organization.
# Use data analytics to inform strategic decisions related to pricing, marketing, and resource allocation.
# Implement systems for regular performance reviews and adjustments based on insights derived from the data.
#
# Evaluate the performance of different marketing channels and campaigns.
# Optimize marketing strategies to reach target audiences effectively.
# Enhance the visibility of the hotel through strategic marketing initiatives.
#
# Identify and mitigate potential risks, such as high cancellation rates or inefficient resource allocation.
# Implement strategies to handle unforeseen challenges, ensuring business continuity.
#
# Establish a feedback loop based on customer reviews and feedback.
# Continuously analyze and refine operational processes based on performance metrics.
# Stay abreast of industry trends and technological advancements to remain competitive.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# +### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# connect drive with collab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df = pd.read_csv("/content/drive/MyDrive/Hotel Bookings.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# First five rows of the data
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
# Last five rows of data
df.tail().T
# Out:
#                                        119385      119386      119387  \
# hotel                              City Hotel  City Hotel  City Hotel
# is_canceled                                 0           0           0
# lead_time                                  23         102          34
# arrival_date_year                        2017        2017        2017
# arrival_date_month                     August      August      August
# arrival_date_week_number                   35          35          35
# arrival_date_day_of_month                  30          31          31
# stays_in_weekend_nights                     2           2           2
# stays_in_week_nights                        5           5           5
# adults                                      2           3           2
# children                                  0.0         0.0         0.0
# babies                                      0           0           0
# ...

# %%
# Random five rows of the data
df.sample(5)
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 51926    City Hotel            0        316               2016
# 920    Resort Hotel            1        117               2015
# 18772  Resort Hotel            0         11               2015
# 49790    City Hotel            1        103               2016
# 38774  Resort Hotel            0          0               2017
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 51926                May                        22                         26
# 920               August                        32                          5
# 18772           November                        48                         27
# 49790              April                        17                         19
# 38774               July                        30                         27
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicate = df.duplicated()
duplicate.value_counts()
# There are 31994 duplicate values
# Out:
# False    87396
# True     31994
# Name: count, dtype: int64

# %%
sns.countplot(x = df.duplicated())
plt.title('Duplicate Values')
plt.plot()
# Out:
# []

# %%
# Dropping duplicate values
df.drop_duplicates(inplace = True)

# %%
duplicate = df.duplicated()
duplicate.value_counts()
# Out:
# False    87396
# Name: count, dtype: int64

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
miss = df.isna().sum()
miss.sort_values(ascending = False)
# Out:
# company                           82137
# agent                             12193
# country                             452
# children                              4
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# hotel                                 0
# previous_cancellations                0
# days_in_waiting_list                  0
# customer_type                         0
# adr                                   0
# required_car_parking_spaces           0
# total_of_special_requests             0
# reservation_status                    0
# previous_bookings_not_canceled        0
# is_repeated_guest                     0
# is_canceled                           0
# distribution_channel                  0
# market_segment                        0
# meal                                  0
# babies                                0
# ...

# %%
# Visualizing the missing values
sns.heatmap(df.isnull(), cbar=False)
plt.xlabel("Name of Columns")
plt.title("Missing values in column")
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# In this dataset there are 32 columns and 119390 rows. in this rows some are duplicate and null so we should handle that.
#
# company columns the most missing values and then agent has the missing values children has only 4 missing values and country column has 488 missing values
#
# In this dataset there is good data for analyzing the market of that hotel and also with some strategy, we can increase the number of new customer and also the number of repeated customer.
#
# This dataset appears to be rich with information about hotel reservations, guest demographics, and booking details. Analyzing this data can provide insights into booking patterns, customer preferences, and factors influencing cancellations.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
col = df.columns
print(col)
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  87396.000000  87396.000000       87396.000000
# mean       0.274898     79.891368        2016.210296
# std        0.446466     86.052325           0.686102
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     11.000000        2016.000000
# 50%        0.000000     49.000000        2016.000000
# 75%        1.000000    125.000000        2017.000000
# max        1.000000    737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              87396.000000               87396.000000
# mean                  26.838334                  15.815541
# std                   13.674572                   8.835146
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   27.000000                  16.000000
# 75%                   37.000000                  23.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# 'hotel': Type of hotel (e.g., resort hotel, city hotel).
#
# 'is_canceled': Binary variable indicating whether the reservation was canceled (1) or not (0).
#
# 'lead_time': Number of days between booking and the arrival date.
#
# 'arrival_date_year': The year of arrival.
#
# 'arrival_date_month': The month of arrival.
#
# 'arrival_date_week_number': The week number of the year for the arrival date.
#
# 'arrival_date_day_of_month': The day of the month for the arrival date.
#
# 'stays_in_weekend_nights': Number of weekend nights (Saturday or Sunday) stayed.
#
# 'stays_in_week_nights': Number of weekday nights stayed.
#
# 'adults': Number of adults in the reservation.
#
# 'children': Number of children in the reservation.
#
# 'babies': Number of babies in the reservation.
#
# 'meal': Type of meal booked (e.g., Bed & Breakfast, Half Board).
#
# 'country': Country of origin of the guest.
#
# 'market_segment': Market segment designation (e.g., Online Travel Agents, Corporate).
#
# 'distribution_channel': Distribution channel through which the reservation was made.
#
# 'is_repeated_guest': Binary variable indicating whether the guest is a repeated guest (1) or not (0).
#
# 'previous_cancellations': Number of previous cancellations by the guest.
#
# 'previous_bookings_not_canceled': Number of previous bookings that were not canceled by the guest.
#
# 'reserved_room_type': Type of room reserved.
#
# 'assigned_room_type': Type of room assigned.
#
# 'booking_changes': Number of changes made to the booking.
#
# 'deposit_type': Type of deposit made for the reservation.
#
# 'agent': ID code representing the booking agent.
#
# 'company': ID code representing the company.
#
# 'days_in_waiting_list': Number of days the booking was on the waiting list before confirmed.
#
# 'customer_type': Type of booking customer
#
# 'adr': Average Daily Rate, representing the average rental income per paid occupied room per night.
#
# 'required_car_parking_spaces': Number of car parking spaces required by the guest.
#
# 'total_of_special_requests': Total number of special requests made by the guest.
#
# 'reservation_status': Final status of the reservation (e.g., Checked Out).
#
# 'reservation_status_date': Date at which the reservation status was last updated.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in col:
  print(df[i].unique())
# Out:
# ['Resort Hotel' 'City Hotel']
# [0 1]
# [342 737   7  13  14   0   9  85  75  23  35  68  18  37  12  72 127  78
#   48  60  77  99 118  95  96  69  45  40  15  36  43  70  16 107  47 113
#   90  50  93  76   3   1  10   5  17  51  71  63  62 101   2  81 368 364
#  324  79  21 109 102   4  98  92  26  73 115  86  52  29  30  33  32   8
#  100  44  80  97  64  39  34  27  82  94 110 111  84  66 104  28 258 112
#   65  67  55  88  54 292  83 105 280 394  24 103 366 249  22  91  11 108
#  106  31  87  41 304 117  59  53  58 116  42 321  38  56  49 317   6  57
#   19  25 315 123  46  89  61 312 299 130  74 298 119  20 286 136 129 124
#  327 131 460 140 114 139 122 137 126 120 128 135 150 143 151 132 125 157
#  147 138 156 164 346 159 160 161 333 381 149 154 297 163 314 155 323 340
#  356 142 328 144 336 248 302 175 344 382 146 170 166 338 167 310 148 165
#  172 171 145 121 178 305 173 152 354 347 158 185 349 183 352 177 200 192
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
df.isna().sum().sort_values(ascending = False)
# Out:
# company                           82137
# agent                             12193
# country                             452
# children                              4
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# hotel                                 0
# previous_cancellations                0
# days_in_waiting_list                  0
# customer_type                         0
# adr                                   0
# required_car_parking_spaces           0
# total_of_special_requests             0
# reservation_status                    0
# previous_bookings_not_canceled        0
# is_repeated_guest                     0
# is_canceled                           0
# distribution_channel                  0
# market_segment                        0
# meal                                  0
# babies                                0
# ...

# %%
df.drop(['company'],axis = 1,inplace = True)

# %%
df.drop(['agent'],axis = 1,inplace = True)

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# ...

# %%
# Write your code to make your dataset analysis ready.
df['children'] = df['children'].replace(np.nan, 0)
# all these columns company, agent, children is a float data type so i convert it with 0.

# %%
df[['country']] = df[['country']].replace(np.nan, 'other')
# country na values convert it to other country

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119390 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df = df.astype({'children':'int64'})
# change the data type of the columns children, agent, company from float to int

# %%
df['total_days'] = df['stays_in_weekend_nights'] + df['stays_in_week_nights']
# make a column of total days which is the sum of stay in weekend nights and stays in weekend nights

# %%
df['total_people'] = df['adults']+ df['children']+ df['babies']
# make a column of total people which is the sum of adults, children, babies

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# I found that there are some missing and duplicate values and then i fill na values and drop duplicate values.
#
# I found some columns with wrong data type so i convert it with the right data type.
#
# I add some more columns on this data.
#
# Now it's ready to visulize and find some patterns.

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# # U - Univariate Analysis

# %% [markdown]
# #### Chart - 1

# %% [markdown]
# **Q1. What are the peak booking periods throughout the year ?**

# %%
# Chart - 1 visualization code
cust = df.groupby('arrival_date_month').count()['is_canceled'].sort_values(ascending = False).reset_index()
plt.figure(figsize = (12,5))
sns.lineplot(data = cust,x = 'arrival_date_month',y = cust['is_canceled'].sort_values(ascending = False), marker='o', color='blue')
plt.xlabel('Months')
plt.ylabel('Number of customer')
plt.plot()
# Out:
# []

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line chart is well-suited for displaying trends over time. In this case, i want to visualize how the number of bookings changes from month to month.
#
# A line chart visually connects data points with lines, emphasizing the overall trend. This is helpful when you want to show the flow or pattern of the data over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# I found that august is the peak season of hotel booking throught the year.
#
# July is second highest booking month of the year.
#
# There is very few booking in the month of january.
#
# Top 5 months of high booking:-
# 1.August
# 2.July
# 3.May
# 4.April
# 5.June

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# Understanding the peak booking periods can help the business optimize resource allocation during high-demand times. This can lead to improved customer satisfaction, as the hotel can better cater to the needs of guests during busy periods.
#
#
# **Potential Negative Impact:-**
#
# If the business solely focuses on short-term gains, there's a risk of sacrificing long-term customer satisfaction. For example, aggressive pricing strategies during peak periods may lead to dissatisfaction if quality is compromised.

# %% [markdown]
# #### Chart - 2

# %% [markdown]
# **Q2. What is the distribution of customer demographics (by country) ?**

# %%
# Chart - 2 visualization code
a = df['country'].value_counts().sort_values(ascending = False)[:10]
b = a[:10].values
plt.figure(figsize = (12,5))
sns.barplot(x = a.index, y = a.values)
plt.xlabel('Country')
plt.ylabel('Number of customer')
plt.title('Top 10 country with highest customer')
plt.plot()
# Out:
# []

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Count plots are specifically designed for displaying the distribution of categorical variables. Each category is represented by a separate bar.
#
#
# The height of each bar represents the frequency or count of each category, making it easy to compare the distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# I found top 10 country which is the highest customer.
# top 3 countries are:-
# 1. PRT
# 2. GBR
# 3. FRA
#
# NLD is in the 10 position.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:** Understanding the top countries allows for more effective and targeted marketing strategies tailored to the preferences and behaviors of customers from these regions. This can lead to increased customer engagement and loyalty.
#
# **Positive Impact:** Adapting services to align with the cultural preferences of customers from top countries can enhance the overall customer experience, potentially leading to positive reviews, word-of-mouth referrals, and repeat business.
#
# **Negative Impact:** If the business becomes overly dependent on the top customer countries and neglects diversification, external factors affecting those specific markets (e.g., economic downturns, geopolitical instability) could lead to vulnerability and negative growth.
#
# **Negative Impact:** If negative feedback or dissatisfaction from customers in the top countries is not addressed promptly, it could lead to a decline in customer satisfaction, reputation damage, and potential loss of business.

# %% [markdown]
# #### Chart - 3

# %% [markdown]
# Q3. What is the districution of total number of special requests by each month.

# %%
# Chart - 3 visualization code
special = df.groupby('arrival_date_month').sum()['total_of_special_requests']
special = special.sort_values()
plt.figure(figsize = (12,5))
sns.barplot(x = special.index, y = special.values)
plt.xlabel('Months')
plt.ylabel('Number of special requests')
plt.title('Months with special requests')
plt.plot()
# Out:
# []

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Months are categorical data, and bar charts are well-suited for representing the distribution of categorical data.
# Each bar corresponds to a specific category (month), making it easy to compare the counts visually.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# August has the highest number of special requests, indicating a peak demand for additional services during this summer month.
#
# Special requests show a seasonal trend, with higher counts during the summer months (June, July, August) and lower counts in winter (December, January).
#
# There's a noticeable increase in special requests from May to August, indicating a rising demand during the warmer months.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Insight:** Special requests show a seasonal trend, with higher counts during the summer months.
#
# **Positive Impact:** Recognizing the seasonal nature of special requests, the hotel can introduce seasonal service enhancements or packages to cater to the specific needs and preferences of guests during peak seasons.
#
#
#
# **Insight:** There's a noticeable increase in special requests from May to August.
#
# **Negative Impact:** If the hotel fails to anticipate and prepare for the growth in special requests during the warmer months, it may lead to service delays, dissatisfaction among guests, and potential negative reviews.

# %% [markdown]
# #### Chart - 4

# %% [markdown]
# Q4: How are the reserved room types ('reserved_room_type') distributed among the bookings?

# %%
# Chart - 4 visualization code
room = df['reserved_room_type'].value_counts()
plt.figure(figsize = (20,10))
total_bookings = room.sum()
percentages = (room / total_bookings) * 100
plt.pie(percentages, labels=room.index, autopct='%1.1f%%')
plt.title('Distribution of Reserved Room Types')
plt.show()

# %%
room = df['reserved_room_type'].value_counts()
total_bookings = room.sum()
percentages = (room / total_bookings) * 100
percentages
# Out:
# reserved_room_type
# A    64.707767
# D    19.907090
# E     6.921369
# F     3.230125
# G     2.347934
# B     1.143073
# C     1.046959
# H     0.681953
# L     0.006865
# P     0.006865
# Name: count, dtype: float64

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart is effective when you want to show how each part (room type) contributes to the whole (total bookings). The slices of the pie represent the proportions of each category relative to the entire dataset.
#
# Pie charts work well when you have a small number of categories, as it becomes visually challenging to distinguish between slices when there are too many. In this case, you have a manageable number of room types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Insight:** Room type 'A' is the most dominant, representing the majority of bookings with over 72% of the total. This suggests that room type 'A' is the preferred choice among guests.
#
# Room types 'D', 'E', 'F', and 'G' collectively make up a substantial portion of bookings, indicating a limited variation in room preferences among guests.
#
# Rare room types 'P' and 'L' have extremely low percentages, suggesting that they have minimal impact on the overall distribution and are rarely booked.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:** Knowing the dominant room type allows for better resource allocation, ensuring that staff, services, and promotional efforts are optimized for the most frequently booked room type ('A'). This can enhance guest satisfaction and operational efficiency.
#
# **Positive Impact:** With insights into customer preferences for certain room types, marketing strategies can be tailored to highlight the features and benefits of popular rooms, potentially attracting more guests and driving revenue.
#
# **Negative Impact:** While room type 'A' may be dominant, it's essential not to overemphasize it at the expense of other room types. Neglecting less popular room types ('B', 'C', 'H') could lead to negative growth in those segments.
#
# **Negative Impact:** Promotional efforts should be balanced to avoid concentrating solely on the dominant room type. An exclusive focus on 'A' might result in underutilization of other room types

# %% [markdown]
# #### Chart - 5

# %% [markdown]
# Q. Which hotel has the most adr ?

# %%
# Chart - 5 visualization code
adr = df.groupby('hotel')['adr'].sum()
adr = adr.sort_values(ascending = False)
sns.barplot(x = adr.index, y = adr.values)
plt.xlabel('Hotel type')
plt.ylabel('ADR')
plt.title('Hotel Average Daily Rate')
plt.plot()
# Out:
# []

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar plots are effective for comparing quantitative data, such as ADR values for different hotels. Each bar represents a hotel, making it easy to compare their ADRs visually. Bar plots provide a clear and straightforward presentation of data. The length of each bar corresponds directly to the ADR value, allowing stakeholders to quickly identify which hotel has the highest ADR.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# City hotels have a significantly higher Average Daily Rate (ADR) compared to resort hotels.
#
# This insight suggests that city hotels are able to command higher room rates compared to resort hotels and indicating potential differences in market positioning.
#
# It could also reflect variations in demand and pricing strategies between urban and resort destinations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
# Understanding that city hotels command higher ADRs can help management capitalize on this by implementing pricing strategies to further maximize revenue from room bookings.
#
#
#
# **Negative Bussiness impact:**
# If resort hotels are unable to increase their ADRs or differentiate themselves from city hotels, they may face challenges in competing for guests who are willing to pay higher rates. This could lead to stagnant or declining revenue for resort properties.

# %% [markdown]
# # B - Bivariate Analysis

# %% [markdown]
# #### Chart - 6

# %% [markdown]
# Q. How the cancellation rate is related to lead time ?

# %%
cancellation_data = df.groupby('lead_time')['is_canceled'].mean().reset_index()
plt.figure(figsize=(10, 6))
sns.scatterplot(x='lead_time', y='is_canceled', data=cancellation_data)
plt.title('Scatter Plot of Lead Time vs. Cancellation Rate')
plt.xlabel('Lead Time')
plt.ylabel('Cancellation Rate')
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Scatter plots are effective for identifying trends, patterns, or clusters in the data. In this case, you can observe how the 'Cancellation Rate' changes with different values of 'Lead Time.'
#
# Outliers, if present, can be easily identified in a scatter plot. Outliers in the context of 'Lead Time' vs. 'Cancellation Rate' might represent specific situations where the cancellation rate is unexpectedly high or low for certain lead times.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Guests who book well in advance (long lead times) might have a higher likelihood of canceling their reservations compared to those who book closer to the actual stay dates.
#
# If the positive correlation holds, it has operational implications. For example, hotels or booking platforms might need to be attentive to managing cancellations, especially for bookings made far in advance.
#
# **--> There is also some outliers in the chart. So we should not ignore the outliers.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
# Understanding the correlation allows businesses to tailor their strategies based on lead times. This might include targeted marketing, communication, or promotional efforts aimed at reducing cancellations for bookings with longer lead times.
#
# **Positive Business Impact:** Improved anticipation of cancellations allows for more efficient allocation of resources. Operational adjustments can be made to accommodate the potential fluctuations in demand associated with longer lead times.
#
# **Potential Risks for Negative Growth:** If adjustments to policies or communication strategies are not well-received by customers, there's a risk of dissatisfaction. For example, stringent cancellation policies may lead to negative reviews and deter future bookings.

# %% [markdown]
# #### Chart - 7

# %% [markdown]
# Q. What is the relation of deposite type and booking changes ?

# %%
# Chart - 7 visualization code
plt.figure(figsize =(10,5))
sns.boxplot(x = 'deposit_type', y = 'booking_changes', data = df)
plt.title('Box Plot of Deposit Type vs. Booking Changes')
plt.xlabel('Deposit Type')
plt.ylabel('Booking Changes')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Box plots are effective for comparing the distribution of a numerical variable (in this case, "Booking Changes") across different categories of a categorical variable ("Deposit Type"). They provide a visual summary of key distributional characteristics.
#
#  Box plots are particularly useful for identifying outliers in the data.
#
#  Box plots display key summary statistics, including the median, quartiles, and the range of the data. This makes it easy to compare central tendencies and variability across deposit types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Customers who make no deposit may have a higher tendency to make changes (outliers), possibly due to the flexibility of not having financial commitment upfront. However, the majority do not make changes.
#
# Customers with refundable deposits tend to make fewer changes, indicating a more committed booking behavior. The presence of outliers suggests some variability in this behavior.
#
# Customers with non-refundable deposits show a mixed behavior. While there are fewer changes the presence of outliers suggests variability. The financial commitment might deter changes, but exceptions exist.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:** Tailoring deposit policies based on customer behavior can lead to increased customer satisfaction and trust. Aligning policies with observed patterns can encourage more bookings and reduce uncertainties.
#
# **Negative Impact:**If policies become too rigid based on observed patterns, there is a risk of losing customers who value flexibility. Striking the right balance is crucial to avoid deterring potential bookings.

# %% [markdown]
# #### Chart - 8

# %% [markdown]
# Q. How does the lead time (the number of days between booking and arrival) interact with the customer type (e.g., transient, group) in predicting the occurrence of cancellations?

# %%
sns.barplot(x ='customer_type',y = 'lead_time',hue='is_canceled',data = df)
plt.xlabel('Customer Type')
plt.ylabel('lead_time')
plt.title('Lead time and Customer type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are effective for comparing categorical data, such as different customer types, lead times, and cancellation statuses. Each bar represents a category, making it easy to visually compare the frequencies of different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Contract type customers have the highest number of lead times, indicating that they tend to book well in advance. However, they also have the highest number of cancellations, suggesting that despite booking early, a significant portion of their bookings are canceled.
#
# Transient-Party have the 2nd highest number of lead times, but the majority of the booking have been canceled, but Transient-party have the highest number of lead times with no cancellation.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact**
# Tailoring pricing strategies to customer segments can maximize revenue.
#
# Personalizing offerings boosts guest satisfaction and loyalty.
#
# **Negative Impact**
# High cancellations from certain segments lead to revenue loss.
#
# Inefficient resource allocation due to fluctuating demand affects profitability.

# %% [markdown]
# #### Chart - 9

# %% [markdown]
# Q. Is there a relationship between the Special requests and cancelation rate ?

# %%
# Chart - 9 visualization code
df2 = df[df['is_canceled']==1]
sr = df2.groupby('total_of_special_requests')['is_canceled'].count().reset_index()
sns.lineplot(data = sr, x = 'total_of_special_requests', y = 'is_canceled',marker = 'o')
# Out:
# <Axes: xlabel='total_of_special_requests', ylabel='is_canceled'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Line chart is good for showing the continuous data and it is very simple and easy to understand to everyone.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In this chart, i found that there is a strong relationship between special requests and cancellation rate.
#
# As the special requests is decreasing the cancellation rate is increasing and as the special requests is increasing then the cancellation rate is decreasing, so there is a good relationship in this chart showing a strong and valuable insight which we can use in our bussiness decisions.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact**
# By understanding that guests who make more special requests are less likely to cancel their bookings, hotels can focus on providing personalized experiences and amenities tailored to guests' preferences. This can lead to higher guest satisfaction, positive reviews, and increased loyalty.
#
# **Negative Impact**
#  If hotels offer too many incentives or benefits for guests who make special requests, they may overcommit resources and fail to meet guests' expectations. This could lead to dissatisfaction and potentially negative reviews, harming the hotel's reputation and future bookings.

# %% [markdown]
# #### Chart - 10

# %% [markdown]
# Q. Is there a relationship between market segment and the likelihood of cancellation?

# %%
ms = df2.groupby('market_segment')['is_canceled'].count().reset_index()
plt.figure(figsize = (12,5))
sns.barplot(data = ms,y = 'market_segment',x ='is_canceled')
plt.xlabel('Cancelation rate')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart allows you to easily compare cancellation rates across different countries by representing each country as a separate bar. This makes it straightforward to identify countries with higher or lower cancellation rates.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that bookings made through online travel agencies often get canceled the most, followed by group bookings. However, bookings related to aviation, like airline crew accommodations, have the fewest cancellations. These findings can help businesses plan better to reduce cancellations and manage revenue effectively for different types of bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact**
# By identifying market segments with higher cancellation rates, businesses can implement targeted strategies to minimize cancellations and optimize revenue.
#
# **Negative Impact**
# Implementing overly restrictive cancellation policies or targeting specific segments with penalties may alienate customers and lead to negative perceptions of the brand.

# %% [markdown]
# # M - Multivariate Analysis

# %% [markdown]
# #### Chart - 11

# %% [markdown]
# Q. Is there any relationship between Cancellation Rate by Hotel, Customer Type, and Deposit Type ?

# %%
# Chart - 11 visualization code
grouped_data = df.groupby(['hotel', 'customer_type', 'deposit_type']).agg({
    'is_canceled': 'mean'
}).reset_index()

# Create a grouped bar chart
plt.figure(figsize=(10, 5))
sns.barplot(x='hotel', y='is_canceled', hue='customer_type', data=grouped_data)
plt.title('Cancellation Rate by Hotel, Customer Type, and Deposit Type')
plt.xlabel('Hotel Type')
plt.ylabel('Cancellation Rate')
plt.legend(title='Customer Type', loc='upper right')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The grouped bar chart allows you to compare the cancellation rates across different categories within each main category.
#
# The legend in the chart helps in clearly identifying which colors represent different customer types, making it easier for the viewer to understand the information presented.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **City Hotel:**
#
# **Group:** Shows a very low cancellation rate, suggesting that group bookings in city hotels tend to be more stable and have a lower likelihood of cancellations.
#
# **Transient:** Has a high cancellation rate of around 6, indicating that transient bookings are more likely to be canceled.
#
#
#
# **Resort Hotel:**
#
# **Group:** Similar to city hotels, group bookings have a very low cancellation rate, indicating a consistent trend across hotel types.
#
# **Transient**: Highest cancellation rate, highlighting that transient bookings in resort hotels are particularly prone to cancellations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:** Hotel management can focus on targeted marketing efforts to attract more group bookings.
#
# **Positive Impact:** hotel can implement customer engagement strategies, loyalty programs, or personalized communication to enhance the commitment of transient customers.
#
# **Negative Impact:** Relying solely on group bookings might result in missed opportunities for revenue diversification.

# %% [markdown]
# #### Chart - 12

# %% [markdown]
# Q. What is the relationship between reserved room type and adr ?

# %%
# Chart - 12 visualization code
gb = df.groupby(['customer_type','reserved_room_type'])['adr'].sum().reset_index()
sns.barplot(data=gb, hue='customer_type', y='adr', x='reserved_room_type')
plt.ylabel('Average daily rate')
plt.xlabel('Reserved room type')
plt.title('Grouped Bar Chart of ADR by Room type and Customer type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose the specific chart, a bar chart, because it effectively presents categorical data in a visually clear and straightforward manner.
#
#  The bar chart allows for easy comparison between different categories, such as customer types and reserved room types. Each bar represents a category, making it simple to compare metrics like average daily rate (ADR) or number of bookings across these categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals that transient customer types tend to have the highest ADR across most reserved room types. This suggests that transient customers, who typically book short-term stays, are willing to pay higher prices for accommodations compared to other customer segments.
#
#
#  The chart also provides insights into booking trends by room type, with room type A having the most bookings and room type P having the lowest. This suggests that room type A is in high demand among customers, while room type P may be less popular or less frequently booked.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:**
# By adjusting room rates or offering premium packages targeted at transient customers, the business can optimize revenue and profitability.
#
# By recognizing customer preferences and spending behaviors, the business can tailor its services and offerings to meet customer expectations.
#
# **Negative Impact:**
#  If competitors offer similar or better accommodations at lower prices, the business may face pressure to adjust its pricing strategy to remain competitive. Failure to respond effectively to competitive pricing pressures may result in lost bookings and revenue.
#
#
#
#  While transient customer segments may have higher ADRs, they may also be more price-sensitive or less loyal compared to other customer segments. Relying too heavily on transient customers for revenue may pose risks if market conditions change or if competitors offer more attractive pricing.

# %% [markdown]
# #### Chart - 13

# %% [markdown]
# Q. How does the average daily rate (ADR) vary across different market segments and hotel types?

# %%
# Chart - 13 visualization code
mg = df.groupby(['hotel','market_segment'])['adr'].mean().reset_index()
# size the chart
plt.figure(figsize = (10,5))
# making the chart
sns.barplot(data = mg,hue= 'hotel', x = "market_segment",y = 'adr')
# Label at x axis
plt.xlabel('Market Segment')
# Label at y axis
plt.ylabel('Average Daily Rate (ADR)')
# Title label
plt.title('ADR on different market segment')
# To show the chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are well-suited for comparing values across different categories, such as market segments and hotel types. Each bar represents a distinct category, making it easy to visually compare ADR values between different segments and types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **1.**Direct bookings are the primary revenue source for both city and resort hotels.
#
#
# **2.**Online travel agency bookings also contribute significantly to revenue but tend to yield slightly lower returns compared to direct bookings.
#
#
# **3.**City hotels generally command higher average daily rates (ADRs) than resort hotels.
#
#
# **4.**There are variations in ADR across different market segments, highlighting the importance of targeted marketing and pricing strategies to optimize revenue generation.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
# By identifying areas of strength and weakness in revenue generation, hotels can adjust their offerings and services to enhance competitiveness and attract higher-value guests.
#
# Recognizing the variations in ADR across different market segments and hotel types enables hotels to implement targeted pricing strategies to maximize revenue potential and profitability.
#
# **Negative Business Impact:** Relying heavily on a single market segment, such as direct bookings, may expose hotels to risks associated with fluctuations in demand or changes in consumer behavior. Diversifying the customer base can help mitigate these risks.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
cor_df = df[['is_canceled','lead_time','arrival_date_year','arrival_date_week_number','arrival_date_day_of_month','stays_in_weekend_nights'
,'is_repeated_guest','previous_cancellations','previous_bookings_not_canceled','booking_changes','days_in_waiting_list',
'adr','required_car_parking_spaces','total_of_special_requests','total_days','total_people']]

plt.figure(figsize = (15,10))
sns.heatmap(cor_df.corr(),annot = True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Heatmaps use a color gradient to represent the strength and direction of correlations, providing an immediate and intuitive visual understanding of the relationships within the dataset.
#
# Heatmaps are scalable to large datasets, making them suitable for visualizing correlations in projects with numerous variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# I found that there is not much correlation between columns but there are some columns like required car parking and is cancelled columns have little correlation that means car parking can be a reason for cancelling the booking

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %% [markdown]
# Q. How do the numerical variables such as lead time, total number of special requests, average daily rate (ADR), and number of booking changes relate to each other, considering the customer type?

# %%
# Pair Plot visualization code
numerical_vars = ['lead_time', 'total_of_special_requests', 'adr', 'booking_changes', 'customer_type']
sns.pairplot(df[numerical_vars], hue='customer_type', diag_kind='hist')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot allows you to simultaneously visualize relationships between multiple pairs of variables in a single chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# When customer make more special requests (like asking for specific room features), they tend to book their stay closer to their arrival date.
#
#
# Similarly, when guests make more changes to their bookings, they also tend to book closer to their arrival date.
#
# the observation that lead time tends to decrease as the total number of special requests increases suggests a possible inverse relationship between these two variables.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# 1.   July is the peak season of the booking so make some strategy to increase the number of bookings and also make some stratrgy to increase the bookings other than the peak months.
# 2.   PRT country people books the hotel most so we can make some loyalty program to increase the trust with the people and we can also do some target marketing for this location to increse our bookings and also make some strategy to increase the booking with other country than the PRT.
# 3.   July and August has the highest number of special requests so we can also make some strategy for this insight.
# 4.  Room type A has the highest number of bookings so we can increase the service of this room type and also other room type to increase the booking of all the rooms.
# 5.  City hotel has the highest number of adr than the resort hotel.
# 6.  In the city hotel and resort hotel, transient type customer has the highest number of cancelation rate.
# 7. roomtype has the highest number of adr by transient type customer.
# 8.  Direct and online ta market segment has the highest number of adr in both city hotel and resort hotel.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# We can make some strategy to increase our sales and also the number of booking and aims to decrease the cancelation rate. With this analysis we can draw good conclusion for our business perspective and there are some great relation between some columns which help us to make decisions in our business and also help us to predict the future booking cancelation, we can also increase the number of customer and also increase the retention rate and Aims to decrease the lead time with the strategy.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
